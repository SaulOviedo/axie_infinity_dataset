# %%
import requests
import pandas as pd
import time
from random import randint, choice

# %%
URL_API = "https://graphql-gateway.axieinfinity.com/graphql"

headers = {
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'es-ES,es;q=0.9,en;q=0.8',
    'cache-control': 'no-cache',
    'content-length': '1010',
    'content-type': 'application/json',
    'cookie': '_ga=GA1.2.581236636.1631802371; _gid=GA1.2.1060654813.1631802371; cf_clearance=ps3wfb304R6sKsauq5bsfRJh.xrDvMo2TWlLub0Vf2s-1631892833-0-250; _gat_gtag_UA_150383258_1=1',
    'origin': 'https://marketplace.axieinfinity.com',
    'pragma': 'no-cache',
    'referer': 'https://marketplace.axieinfinity.com/',
    'sec-ch-ua': '"Google Chrome";v="93", " Not;A Brand";v="99", "Chromium";v="93"',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36',
}

# %%
query = """query GetAxieBriefList($auctionType: AuctionType, $criteria: AxieSearchCriteria, $from: Int, $sort: SortBy, $size: Int, $owner: String) {
  axies(auctionType: $auctionType, criteria: $criteria, from: $from, sort: $sort, size: $size, owner: $owner) {
    total
    results {
      ...AxieDetail
      transferHistory(from: $from, size: $size) {
        ...TransferRecords
        __typename
      }
      ethereumTransferHistory(from: $from, size: $size) {
        ...TransferRecords
        __typename
      }   
      __typename
    }
    __typename
  }
}

fragment AxieDetail on Axie {
  id
  image
  class
  chain
  name
  birthDate
  bodyShape
  sireId
  sireClass
  matronId
  matronClass
  stage
  title
  breedCount
  level
  stats {
    ...AxieStats
    __typename
  }
  __typename
}

fragment AxieStats on AxieStats {
  hp
  speed
  skill
  morale
  __typename
}

fragment TransferRecords on TransferRecords {
  total
  results {
    from
    to
    timestamp
    txHash
    withPrice
    __typename
  }
  __typename
}
"""

# %%
payload = {
    "operationName": "GetAxieBriefList",
    "variables": {
        "from": 0,
        "size": 10,
        "sort": "Latest",
        "auctionType": "Sale",
        "owner": None,
        "criteria": {
            "region": None,
            "parts": None,
            "bodyShapes": None,
            "classes": None,
            "stages": [
                4
            ],
            "numMystic": None,
            "pureness": None,
            "title": None,
            "breedable": None,
            "breedCount": None,
            "hp": [],
            "skill": [],
            "speed": [],
            "morale": []
        }
    },
    "query": query
}

# %%
def get_random_ua():
    with open('agents.txt', encoding='utf-8') as f:
        lines = f.readlines()
    return  choice(lines).replace('\n','')

# %%
TOTAL = requests.post(URL_API, json=payload).json()['data']['axies']['total']

START = 0
SIZE = 75
NO_REQUESTS = TOTAL // SIZE
CHECKPOINTS = SIZE * 100 # Guarda un Checkpoint cada 5000 requests
col_dtypes = {
    'id':'uint32',
    'sireId':'uint16',
    'matronId':'uint16',
    'birthDate':'uint32',
    'stage':'uint8',
    'breedCount':'uint8',
    'level':'uint8',
    'hp':'uint8',
    'speed':'uint8',
    'skill':'uint8',
    'morale':'uint8',
    'withPrice': 'float32'
}

payload['variables']['size'] = SIZE

df = pd.DataFrame()

for i in range(0, NO_REQUESTS * SIZE, SIZE):
  
    if i % (10 * SIZE ) == 0: print('--> Getting from', i, 'To', i + SIZE);

    payload['variables']['from'] = i
    headers['user-agent'] = get_random_ua()
    try:
        time.sleep(randint(3,15))
        res = requests.post(URL_API, json=payload, headers=headers)
        if res.status_code == 200:
            axies = res.json()['data']['axies']['results']
        else:
            raise 'Invalid code'

    except:
        print('------> Error Batch #', i, '-', i+SIZE)
        axies = []

    transactions = []
    for axie in axies:
        stats = axie.pop('stats')
        axie = { **axie, **stats}
        txns = axie.pop('ethereumTransferHistory')['results'] + axie.pop('transferHistory')['results']
        transactions += [ {**axie, **t} for t in txns ]

    try:
        transactions = pd.DataFrame(transactions).astype(col_dtypes).drop(columns='__typename')
        transactions.withPrice = transactions.withPrice / 1e18
        df = df.append(transactions)
    
    except:
        print('------> Empty Batch #', i, '-', i+SIZE)

    if i and ( i + SIZE ) % CHECKPOINTS == 0 and not df.empty:
        print('---------> Saving checkpoint!')
        df = df.set_index('txHash')
        df.to_csv(f'./dataset/dataset_{ i + SIZE - CHECKPOINTS }_{ i + SIZE }.csv')
        df = pd.DataFrame()

print('---------> Saving last checkpoint!')
if not df.empty: df = df.set_index('txHash');
df.to_csv(f'./dataset/dataset_last.csv')
# Out:
# --> Getting from 0 To 75
# ------> Error Batch # 0 - 75
# ------> Empty Batch # 0 - 75
# --> Getting from 750 To 825
# --> Getting from 1500 To 1575
# --> Getting from 2250 To 2325
# --> Getting from 3000 To 3075
# --> Getting from 3750 To 3825
# --> Getting from 4500 To 4575
# --> Getting from 5250 To 5325
# --> Getting from 6000 To 6075
# --> Getting from 6750 To 6825
# ------> Error Batch # 7275 - 7350
# ------> Empty Batch # 7275 - 7350
# ---------> Saving checkpoint!
# --> Getting from 7500 To 7575
# --> Getting from 8250 To 8325
# --> Getting from 9000 To 9075
# --> Getting from 9750 To 9825
# ------> Empty Batch # 9975 - 10050
# ------> Empty Batch # 10050 - 10125
# ------> Empty Batch # 10125 - 10200
# ------> Empty Batch # 10200 - 10275
# ------> Empty Batch # 10275 - 10350
# ------> Empty Batch # 10350 - 10425
# ------> Empty Batch # 10425 - 10500
# --> Getting from 10500 To 10575
# ------> Empty Batch # 10500 - 10575
# ------> Empty Batch # 10575 - 10650
# ------> Empty Batch # 10650 - 10725
# ------> Empty Batch # 10725 - 10800
# ------> Empty Batch # 10800 - 10875
# ------> Empty Batch # 10875 - 10950
# ------> Error Batch # 10950 - 11025
# ------> Empty Batch # 10950 - 11025
# ------> Empty Batch # 11025 - 11100
# ------> Empty Batch # 11100 - 11175
# ------> Empty Batch # 11175 - 11250
# --> Getting from 11250 To 11325
# ------> Empty Batch # 11250 - 11325
# ------> Empty Batch # 11325 - 11400
# ------> Empty Batch # 11400 - 11475
# ------> Empty Batch # 11475 - 11550
# ------> Empty Batch # 11550 - 11625
# ------> Empty Batch # 11625 - 11700
# ------> Empty Batch # 11700 - 11775
# ------> Empty Batch # 11775 - 11850
# ------> Empty Batch # 11850 - 11925
# ------> Empty Batch # 11925 - 12000
# --> Getting from 12000 To 12075
# ------> Empty Batch # 12000 - 12075
# ------> Empty Batch # 12075 - 12150
# ------> Empty Batch # 12150 - 12225
# ------> Empty Batch # 12225 - 12300
# ------> Empty Batch # 12300 - 12375
# ------> Empty Batch # 12375 - 12450
# ------> Empty Batch # 12450 - 12525
# ------> Empty Batch # 12525 - 12600
# ------> Empty Batch # 12600 - 12675
# ------> Empty Batch # 12675 - 12750
# --> Getting from 12750 To 12825
# ------> Empty Batch # 12750 - 12825
# ------> Empty Batch # 12825 - 12900
# ------> Empty Batch # 12900 - 12975
# ------> Empty Batch # 12975 - 13050
# ------> Empty Batch # 13050 - 13125
# ------> Empty Batch # 13125 - 13200
# ------> Empty Batch # 13200 - 13275
# ------> Empty Batch # 13275 - 13350
# ------> Empty Batch # 13350 - 13425
# ------> Empty Batch # 13425 - 13500
# --> Getting from 13500 To 13575
# ------> Empty Batch # 13500 - 13575
# ------> Empty Batch # 13575 - 13650
# ------> Empty Batch # 13650 - 13725
# ------> Empty Batch # 13725 - 13800
# ------> Empty Batch # 13800 - 13875
# ------> Empty Batch # 13875 - 13950
# ------> Empty Batch # 13950 - 14025
# ------> Empty Batch # 14025 - 14100
# ------> Empty Batch # 14100 - 14175
# ------> Empty Batch # 14175 - 14250
# --> Getting from 14250 To 14325
# ------> Empty Batch # 14250 - 14325
# ------> Empty Batch # 14325 - 14400
# ------> Empty Batch # 14400 - 14475
# ------> Empty Batch # 14475 - 14550
# ------> Empty Batch # 14550 - 14625
# ------> Empty Batch # 14625 - 14700
# ------> Empty Batch # 14700 - 14775
# ------> Empty Batch # 14775 - 14850
# ------> Empty Batch # 14850 - 14925
# ------> Empty Batch # 14925 - 15000
# ---------> Saving checkpoint!
# --> Getting from 15000 To 15075
# ------> Empty Batch # 15000 - 15075
# ------> Empty Batch # 15075 - 15150
# ------> Empty Batch # 15150 - 15225
# ------> Empty Batch # 15225 - 15300
# ------> Empty Batch # 15300 - 15375
# ------> Empty Batch # 15375 - 15450
# ------> Empty Batch # 15450 - 15525
# ------> Empty Batch # 15525 - 15600
# ------> Empty Batch # 15600 - 15675
# ------> Empty Batch # 15675 - 15750
# --> Getting from 15750 To 15825
# ------> Empty Batch # 15750 - 15825
# ------> Empty Batch # 15825 - 15900
# ------> Empty Batch # 15900 - 15975
# ------> Empty Batch # 15975 - 16050
# ------> Empty Batch # 16050 - 16125
# ------> Empty Batch # 16125 - 16200
# ------> Empty Batch # 16200 - 16275
# ------> Empty Batch # 16275 - 16350
# ------> Empty Batch # 16350 - 16425
# ------> Empty Batch # 16425 - 16500
# --> Getting from 16500 To 16575
# ------> Empty Batch # 16500 - 16575
# ------> Empty Batch # 16575 - 16650
# ------> Empty Batch # 16650 - 16725
# ------> Empty Batch # 16725 - 16800
# ------> Empty Batch # 16800 - 16875
# ------> Empty Batch # 16875 - 16950
# ------> Empty Batch # 16950 - 17025
# ------> Empty Batch # 17025 - 17100
# ------> Empty Batch # 17100 - 17175
# ------> Empty Batch # 17175 - 17250
# --> Getting from 17250 To 17325
# ------> Empty Batch # 17250 - 17325
# ------> Empty Batch # 17325 - 17400
# ------> Empty Batch # 17400 - 17475
# ------> Empty Batch # 17475 - 17550
# ------> Empty Batch # 17550 - 17625
# ------> Empty Batch # 17625 - 17700
# ------> Empty Batch # 17700 - 17775
# ------> Empty Batch # 17775 - 17850
# ------> Empty Batch # 17850 - 17925
# ------> Empty Batch # 17925 - 18000
# --> Getting from 18000 To 18075
# ------> Empty Batch # 18000 - 18075
# ------> Empty Batch # 18075 - 18150
# ------> Empty Batch # 18150 - 18225
# ------> Empty Batch # 18225 - 18300
# ------> Empty Batch # 18300 - 18375
# ------> Empty Batch # 18375 - 18450
# ------> Empty Batch # 18450 - 18525
# ------> Empty Batch # 18525 - 18600
# ------> Empty Batch # 18600 - 18675
# ------> Empty Batch # 18675 - 18750
# --> Getting from 18750 To 18825
# ------> Empty Batch # 18750 - 18825
# ------> Empty Batch # 18825 - 18900
# ------> Empty Batch # 18900 - 18975
# ------> Empty Batch # 18975 - 19050
# ------> Empty Batch # 19050 - 19125
# ------> Empty Batch # 19125 - 19200
# ------> Empty Batch # 19200 - 19275
# ------> Empty Batch # 19275 - 19350
# ------> Empty Batch # 19350 - 19425
# ------> Empty Batch # 19425 - 19500
# --> Getting from 19500 To 19575
# ------> Empty Batch # 19500 - 19575
# ------> Empty Batch # 19575 - 19650
# ------> Empty Batch # 19650 - 19725
# ------> Empty Batch # 19725 - 19800
# ------> Empty Batch # 19800 - 19875
# ------> Empty Batch # 19875 - 19950
# ------> Empty Batch # 19950 - 20025
# ------> Empty Batch # 20025 - 20100
# ------> Empty Batch # 20100 - 20175
# ------> Empty Batch # 20175 - 20250
# --> Getting from 20250 To 20325
# ------> Empty Batch # 20250 - 20325
# ------> Empty Batch # 20325 - 20400
# ------> Empty Batch # 20400 - 20475
# ------> Empty Batch # 20475 - 20550
# ------> Empty Batch # 20550 - 20625
# ------> Empty Batch # 20625 - 20700
# ------> Empty Batch # 20700 - 20775
# ------> Empty Batch # 20775 - 20850
# ------> Empty Batch # 20850 - 20925
# ------> Empty Batch # 20925 - 21000
# --> Getting from 21000 To 21075
# ------> Error Batch # 21000 - 21075
# ------> Empty Batch # 21000 - 21075
# ------> Empty Batch # 21075 - 21150
# ------> Empty Batch # 21150 - 21225
# ------> Empty Batch # 21225 - 21300
# ------> Empty Batch # 21300 - 21375
# ------> Empty Batch # 21375 - 21450
# ------> Empty Batch # 21450 - 21525
# ------> Empty Batch # 21525 - 21600
# ------> Empty Batch # 21600 - 21675
# ------> Empty Batch # 21675 - 21750
# --> Getting from 21750 To 21825
# ------> Empty Batch # 21750 - 21825
# ------> Empty Batch # 21825 - 21900
# ------> Empty Batch # 21900 - 21975
# ------> Empty Batch # 21975 - 22050
# ------> Empty Batch # 22050 - 22125
# ------> Empty Batch # 22125 - 22200
# ------> Empty Batch # 22200 - 22275
# ------> Empty Batch # 22275 - 22350
# ------> Empty Batch # 22350 - 22425
# ------> Empty Batch # 22425 - 22500
# --> Getting from 22500 To 22575
# ------> Empty Batch # 22500 - 22575
# ------> Empty Batch # 22575 - 22650
# ------> Empty Batch # 22650 - 22725
# ------> Empty Batch # 22725 - 22800
# ------> Empty Batch # 22800 - 22875
# ------> Empty Batch # 22875 - 22950
# ------> Empty Batch # 22950 - 23025
# ------> Empty Batch # 23025 - 23100
# ------> Empty Batch # 23100 - 23175
# ------> Empty Batch # 23175 - 23250
# --> Getting from 23250 To 23325
# ------> Empty Batch # 23250 - 23325
# ------> Empty Batch # 23325 - 23400
# ------> Empty Batch # 23400 - 23475
# ------> Empty Batch # 23475 - 23550
# ------> Empty Batch # 23550 - 23625
# ------> Empty Batch # 23625 - 23700
# ------> Empty Batch # 23700 - 23775
# ------> Empty Batch # 23775 - 23850
# ------> Empty Batch # 23850 - 23925
# ------> Empty Batch # 23925 - 24000
# --> Getting from 24000 To 24075
# ------> Empty Batch # 24000 - 24075
# ------> Empty Batch # 24075 - 24150
# ------> Empty Batch # 24150 - 24225
# ------> Empty Batch # 24225 - 24300
# ------> Empty Batch # 24300 - 24375
# ------> Empty Batch # 24375 - 24450
# ------> Empty Batch # 24450 - 24525
# ------> Empty Batch # 24525 - 24600
# ------> Empty Batch # 24600 - 24675
# ------> Empty Batch # 24675 - 24750
# --> Getting from 24750 To 24825
# ------> Empty Batch # 24750 - 24825
# ------> Empty Batch # 24825 - 24900
# ------> Empty Batch # 24900 - 24975
# ------> Empty Batch # 24975 - 25050
# ------> Empty Batch # 25050 - 25125
# ------> Empty Batch # 25125 - 25200
# ------> Empty Batch # 25200 - 25275
# ------> Empty Batch # 25275 - 25350
# ------> Empty Batch # 25350 - 25425
# ------> Empty Batch # 25425 - 25500
# --> Getting from 25500 To 25575
# ------> Empty Batch # 25500 - 25575
# ------> Empty Batch # 25575 - 25650
# ------> Empty Batch # 25650 - 25725
# ------> Empty Batch # 25725 - 25800
# ------> Empty Batch # 25800 - 25875
# ------> Empty Batch # 25875 - 25950
# ------> Empty Batch # 25950 - 26025
# ------> Empty Batch # 26025 - 26100
# ------> Empty Batch # 26100 - 26175
# ------> Empty Batch # 26175 - 26250
# --> Getting from 26250 To 26325
# ------> Empty Batch # 26250 - 26325
# ------> Empty Batch # 26325 - 26400
# ------> Empty Batch # 26400 - 26475
# ------> Empty Batch # 26475 - 26550
# ------> Empty Batch # 26550 - 26625
# ------> Empty Batch # 26625 - 26700
# ------> Empty Batch # 26700 - 26775
# ------> Empty Batch # 26775 - 26850
# ------> Empty Batch # 26850 - 26925
# ------> Empty Batch # 26925 - 27000
# --> Getting from 27000 To 27075
# ------> Empty Batch # 27000 - 27075
# ------> Empty Batch # 27075 - 27150
# ------> Empty Batch # 27150 - 27225
# ------> Empty Batch # 27225 - 27300
# ------> Empty Batch # 27300 - 27375
# ------> Empty Batch # 27375 - 27450
# ------> Empty Batch # 27450 - 27525
# ------> Empty Batch # 27525 - 27600
# ------> Empty Batch # 27600 - 27675
# ------> Empty Batch # 27675 - 27750
# --> Getting from 27750 To 27825
# ------> Empty Batch # 27750 - 27825
# ------> Empty Batch # 27825 - 27900
# ------> Empty Batch # 27900 - 27975
# ------> Empty Batch # 27975 - 28050
# ------> Empty Batch # 28050 - 28125
# ------> Empty Batch # 28125 - 28200
# ------> Empty Batch # 28200 - 28275
# ------> Empty Batch # 28275 - 28350
# ------> Empty Batch # 28350 - 28425
# ------> Empty Batch # 28425 - 28500
# --> Getting from 28500 To 28575
# ------> Empty Batch # 28500 - 28575
# ------> Empty Batch # 28575 - 28650
# ------> Empty Batch # 28650 - 28725
# ------> Empty Batch # 28725 - 28800
# ------> Empty Batch # 28800 - 28875
# ------> Empty Batch # 28875 - 28950
# ------> Empty Batch # 28950 - 29025
# ------> Empty Batch # 29025 - 29100
# ------> Empty Batch # 29100 - 29175
# ------> Empty Batch # 29175 - 29250
# --> Getting from 29250 To 29325
# ------> Empty Batch # 29250 - 29325
# ------> Empty Batch # 29325 - 29400
# ------> Empty Batch # 29400 - 29475
# ------> Empty Batch # 29475 - 29550
# ------> Empty Batch # 29550 - 29625
# ------> Empty Batch # 29625 - 29700
# ------> Empty Batch # 29700 - 29775
# ------> Empty Batch # 29775 - 29850
# ------> Empty Batch # 29850 - 29925
# ------> Empty Batch # 29925 - 30000
# --> Getting from 30000 To 30075
# ------> Empty Batch # 30000 - 30075
# ------> Empty Batch # 30075 - 30150
# ------> Empty Batch # 30150 - 30225
# ------> Empty Batch # 30225 - 30300
# ------> Empty Batch # 30300 - 30375
# ------> Empty Batch # 30375 - 30450
# ------> Empty Batch # 30450 - 30525
# ------> Empty Batch # 30525 - 30600
# ------> Empty Batch # 30600 - 30675
# ------> Empty Batch # 30675 - 30750
# --> Getting from 30750 To 30825
# ------> Empty Batch # 30750 - 30825
# ------> Empty Batch # 30825 - 30900
# ------> Empty Batch # 30900 - 30975
# ------> Empty Batch # 30975 - 31050
# ------> Empty Batch # 31050 - 31125
# ------> Empty Batch # 31125 - 31200
# ------> Empty Batch # 31200 - 31275
# ------> Empty Batch # 31275 - 31350
# ------> Empty Batch # 31350 - 31425
# ------> Empty Batch # 31425 - 31500
# --> Getting from 31500 To 31575
# ------> Empty Batch # 31500 - 31575
# ------> Empty Batch # 31575 - 31650
# ------> Empty Batch # 31650 - 31725
# ------> Empty Batch # 31725 - 31800
# ------> Empty Batch # 31800 - 31875
# ------> Empty Batch # 31875 - 31950
# ------> Empty Batch # 31950 - 32025
# ------> Empty Batch # 32025 - 32100
# ------> Empty Batch # 32100 - 32175
# ------> Empty Batch # 32175 - 32250
# --> Getting from 32250 To 32325
# ------> Empty Batch # 32250 - 32325
# ------> Empty Batch # 32325 - 32400
# ------> Empty Batch # 32400 - 32475
# ------> Empty Batch # 32475 - 32550
# ------> Empty Batch # 32550 - 32625
# ------> Empty Batch # 32625 - 32700
# ------> Empty Batch # 32700 - 32775
# ------> Empty Batch # 32775 - 32850
# ------> Empty Batch # 32850 - 32925
# ------> Empty Batch # 32925 - 33000
# --> Getting from 33000 To 33075
# ------> Empty Batch # 33000 - 33075
# ------> Empty Batch # 33075 - 33150
# ------> Empty Batch # 33150 - 33225
# ------> Empty Batch # 33225 - 33300
# ------> Empty Batch # 33300 - 33375
# ------> Empty Batch # 33375 - 33450
# ------> Empty Batch # 33450 - 33525
# ------> Empty Batch # 33525 - 33600
# ------> Empty Batch # 33600 - 33675
# ------> Empty Batch # 33675 - 33750
# --> Getting from 33750 To 33825
# ------> Empty Batch # 33750 - 33825
# ------> Empty Batch # 33825 - 33900
# ------> Empty Batch # 33900 - 33975
# ------> Empty Batch # 33975 - 34050
# ------> Empty Batch # 34050 - 34125
# ------> Empty Batch # 34125 - 34200
# ------> Empty Batch # 34200 - 34275
# ------> Empty Batch # 34275 - 34350
# ------> Empty Batch # 34350 - 34425
# ------> Empty Batch # 34425 - 34500
# --> Getting from 34500 To 34575
# ------> Empty Batch # 34500 - 34575
# ------> Empty Batch # 34575 - 34650
# ------> Empty Batch # 34650 - 34725
# ------> Empty Batch # 34725 - 34800
# ------> Empty Batch # 34800 - 34875
# ------> Empty Batch # 34875 - 34950
# ------> Empty Batch # 34950 - 35025
# ------> Empty Batch # 35025 - 35100
# ------> Empty Batch # 35100 - 35175
# ------> Empty Batch # 35175 - 35250
# --> Getting from 35250 To 35325
# ------> Empty Batch # 35250 - 35325
# ------> Empty Batch # 35325 - 35400
# ------> Empty Batch # 35400 - 35475
# ------> Empty Batch # 35475 - 35550
# ------> Empty Batch # 35550 - 35625
# ------> Empty Batch # 35625 - 35700
# ------> Empty Batch # 35700 - 35775
# ------> Empty Batch # 35775 - 35850
# ------> Empty Batch # 35850 - 35925
# ------> Empty Batch # 35925 - 36000
# --> Getting from 36000 To 36075
# ------> Empty Batch # 36000 - 36075
# ------> Empty Batch # 36075 - 36150
# ------> Empty Batch # 36150 - 36225
# ------> Empty Batch # 36225 - 36300
# ------> Empty Batch # 36300 - 36375
# ------> Empty Batch # 36375 - 36450
# ------> Empty Batch # 36450 - 36525
# ------> Empty Batch # 36525 - 36600
# ------> Empty Batch # 36600 - 36675
# ------> Empty Batch # 36675 - 36750
# --> Getting from 36750 To 36825
# ------> Empty Batch # 36750 - 36825
# ------> Empty Batch # 36825 - 36900
# ------> Empty Batch # 36900 - 36975
# ------> Empty Batch # 36975 - 37050
# ------> Empty Batch # 37050 - 37125
# ------> Empty Batch # 37125 - 37200
# ------> Empty Batch # 37200 - 37275
# ------> Empty Batch # 37275 - 37350
# ------> Empty Batch # 37350 - 37425
# ------> Empty Batch # 37425 - 37500
# --> Getting from 37500 To 37575
# ------> Empty Batch # 37500 - 37575
# ------> Empty Batch # 37575 - 37650
# ------> Empty Batch # 37650 - 37725
# ------> Empty Batch # 37725 - 37800
# ------> Empty Batch # 37800 - 37875
# ------> Empty Batch # 37875 - 37950
# ------> Empty Batch # 37950 - 38025
# ------> Empty Batch # 38025 - 38100
# ------> Empty Batch # 38100 - 38175
# ------> Empty Batch # 38175 - 38250
# --> Getting from 38250 To 38325
# ------> Empty Batch # 38250 - 38325
# ------> Empty Batch # 38325 - 38400
# ------> Empty Batch # 38400 - 38475
# ------> Empty Batch # 38475 - 38550
# ------> Empty Batch # 38550 - 38625
# ------> Empty Batch # 38625 - 38700
# ------> Empty Batch # 38700 - 38775
# ------> Empty Batch # 38775 - 38850
# ------> Empty Batch # 38850 - 38925
# ------> Empty Batch # 38925 - 39000
# --> Getting from 39000 To 39075
# ------> Empty Batch # 39000 - 39075
# ------> Empty Batch # 39075 - 39150
# ------> Empty Batch # 39150 - 39225
# ------> Empty Batch # 39225 - 39300
# ------> Empty Batch # 39300 - 39375
# ------> Empty Batch # 39375 - 39450
# ------> Empty Batch # 39450 - 39525
# ------> Empty Batch # 39525 - 39600
# ------> Empty Batch # 39600 - 39675
# ------> Empty Batch # 39675 - 39750
# --> Getting from 39750 To 39825
# ------> Empty Batch # 39750 - 39825
